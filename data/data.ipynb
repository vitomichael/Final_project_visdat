# %%
import pandas as pd

# %%
df = pd.read_csv('./imp_line_covid.csv')
df.sample(10)
# Out:
#        Unnamed: 0                   Country         Lat        Long  \
# 14215       14479  United States of America   40.000000 -100.000000
# 34191       34436                Tajikistan   38.861000   71.276100
# 36721       36984                  Paraguay  -23.442500  -58.443800
# 4437         4529    Bosnia and Herzegovina   43.915900   17.679100
# 42766       42844                     Benin    9.307700    2.315800
# 11656       11879     Sao Tome and Principe    0.186400    6.613100
# 22173       22232                  Barbados   13.193900  -59.543200
# 16661       16884                    Sweden   60.128161   18.643501
# 36853       36911                   Denmark  189.863400  -40.014300
# 23026       23289               Netherlands  107.044200 -264.960300
#
#              Date  confirmed_cases  death_cases  recovered_cases  confirm  \
# 14215  2020-04-20           790264        44647            72329  790,264
# ...

# %%
df.shape
# Out:
# (45886, 18)

# %%
df.nunique()
# Out:
# Unnamed: 0           45886
# Country                160
# Lat                    160
# Long                   160
# Date                   286
# confirmed_cases      17844
# death_cases           5970
# recovered_cases      13913
# confirm              17844
# recovered            13913
# death                 5970
# death1                5970
# daily_conf            4562
# daily_death           1014
# daily_recovered       3739
# daily_conf_f          4562
# daily_recovered_f     3739
# daily_death_f         1014
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# Country              0
# Lat                  0
# Long                 0
# Date                 0
# confirmed_cases      0
# death_cases          0
# recovered_cases      0
# confirm              0
# recovered            0
# death                0
# death1               0
# daily_conf           0
# daily_death          0
# daily_recovered      0
# daily_conf_f         0
# daily_recovered_f    0
# daily_death_f        0
# dtype: int64
